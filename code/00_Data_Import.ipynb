# %% [markdown]
# # ![](https://ga-dash.s3.amazonaws.com/production/assets/logo-9f88ae6c9c3871690e33280fcf557f33.png)  Project 4 - Prediction of Dengue Cases

# %% [markdown]
# ## Part 1 - Data Import

# %% [markdown]
# In this project, we will be working with three datasets:
# 1. Weather Data
# 2. Google Data
# 3. Dengue Data
#
# In this notebook, we will import all three sets of data before commencing data cleaning in the next notebook.

# %%
# importing libraries
import requests
import os

import pandas as pd
import numpy as np
#!pip install chardet
import chardet
from io import BytesIO
from bs4 import BeautifulSoup

#!pip install pytrends
from pytrends.request import TrendReq
import time
import tqdm

import pickle

# %% [markdown]
# ## 1. Weather Data

# %% [markdown]
# For weather data, we will use the [Meteorological Service Singapore website](http://www.weather.gov.sg/climate-historical-daily/). When we click 'Inspect' on the CSV link, we see that there is an underlying .csv file, structured as:
#
# http://www.weather.gov.sg/files/dailydata/DAILYDATA_S24_202307.csv
#
# where S24 refers to the station number, 2023 refers to the year, and 07 refers to the month. Thus, we can run a 'for' loop for all the years, months, and stations in order to create a master CSV file that concatenates all the data together.

# %% [markdown]
# <mark>**WARNING: The entire process of getting weather data takes approximately 4 hours.**</mark>

# %%
#test create soup object with html parser
nea_url = "http://www.weather.gov.sg/climate-historical-daily/"
weather_res = requests.get(nea_url)
weather_soup = BeautifulSoup(weather_res.content, 'html.parser')

# %%
#test search
weather_station = weather_soup.find_all('ul', {'class': 'dropdown-menu'})
weather_station[1]
# Out:
# <ul class="dropdown-menu long-dropdown" role="menu">
# <li><a href="#Admiralty" onclick="setYear('S104')">Admiralty</a></li><li><a href="#Admiralty West" onclick="setYear('S105')">Admiralty West</a></li><li><a href="#Ang Mo Kio" onclick="setYear('S109')">Ang Mo Kio</a></li><li><a href="#Boon Lay (East)" onclick="setYear('S86')">Boon Lay (East)</a></li><li><a href="#Boon Lay (West)" onclick="setYear('S63')">Boon Lay (West)</a></li><li><a href="#Botanic Garden" onclick="setYear('S120')">Botanic Garden</a></li><li><a href="#Buangkok" onclick="setYear('S55')">Buangkok</a></li><li><a href="#Bukit Panjang" onclick="setYear('S64')">Bukit Panjang</a></li><li><a href="#Bukit Timah" onclick="setYear('S90')">Bukit Timah</a></li><li><a href="#Buona Vista" onclick="setYear('S92')">Buona Vista</a></li><li><a href="#Chai Chee" onclick="setYear('S61')">Chai Chee</a></li><li><a href="#Changi" onclick="setYear('S24')">Changi</a></li><li><a href="#Choa Chu Kang (Central)" onclick="setYear('S114')">Choa Chu Kang (Central)</a></li><li><a href="#Choa Chu Kang (South)" onclick="setYear('S121')">Choa Chu Kang (South)</a></li><li><a href="#Choa Chu Kang (West)" onclick="setYear('S11')">Choa Chu Kang (West)</a></li><li><a href="#Clementi" onclick="setYear('S50')">Clementi</a></li><li><a href="#Dhoby Ghaut" onclick="setYear('S118')">Dhoby Ghaut</a></li><li><a href="#East Coast Parkway" onclick="setYear('S107')">East Coast Parkway</a></li><li><a href="#Jurong (East)" onclick="setYear('S39')">Jurong (East)</a></li><li><a href="#Jurong (North)" onclick="setYear('S101')">Jurong (North)</a></li><li><a href="#Jurong (West)" onclick="setYear('S44')">Jurong (West)</a></li><li><a href="#Jurong Island" onclick="setYear('S117')">Jurong Island</a></li><li><a href="#Jurong Pier" onclick="setYear('S33')">Jurong Pier</a></li><li><a href="#Kampong Bahru" onclick="setYear('S31')">Kampong Bahru</a></li><li><a href="#Kent Ridge" onclick="setYear('S71')">Kent Ridge</a></li><li><a href="#Khatib" onclick="setYear('S122')">Khatib</a></li><li><a href="#Kranji Reservoir" onclick="setYear('S66')">Kranji Reservoir</a></li><li><a href="#Lim Chu Kang" onclick="setYear('S112')">Lim Chu Kang</a></li><li><a href="#Lower Peirce Reservoir" onclick="setYear('S08')">Lower Peirce Reservoir</a></li><li><a href="#Macritchie Reservoir" onclick="setYear('S07')">Macritchie Reservoir</a></li><li><a href="#Mandai" onclick="setYear('S40')">Mandai</a></li><li><a href="#Marina Barrage" onclick="setYear('S108')">Marina Barrage</a></li><li><a href="#Marine Parade" onclick="setYear('S113')">Marine Parade</a></li><li><a href="#Newton" onclick="setYear('S111')">Newton</a></li><li><a href="#Nicoll Highway" onclick="setYear('S119')">Nicoll Highway</a></li><li><a href="#Pasir Panjang" onclick="setYear('S116')">Pasir Panjang</a></li><li><a href="#Pasir Ris (Central)" onclick="setYear('S94')">Pasir Ris (Central)</a></li><li><a href="#Pasir Ris (West)" onclick="setYear('S29')">Pasir Ris (West)</a></li><li><a href="#Paya Lebar" onclick="setYear('S06')">Paya Lebar</a></li><li><a href="#Pulau Ubin" onclick="setYear('S106')">Pulau Ubin</a></li><li><a href="#Punggol" onclick="setYear('S81')">Punggol</a></li><li><a href="#Queenstown" onclick="setYear('S77')">Queenstown</a></li><li><a href="#Seletar" onclick="setYear('S25')">Seletar</a></li><li><a href="#Semakau Island" onclick="setYear('S102')">Semakau Island</a></li><li><a href="#Sembawang" onclick="setYear('S80')">Sembawang</a></li><li><a href="#Sentosa Island" onclick="setYear('S60')">Sentosa Island</a></li><li><a href="#Serangoon" onclick="setYear('S36')">Serangoon</a></li><li><a href="#Serangoon North" onclick="setYear('S110')">Serangoon North</a></li><li><a href="#Simei" onclick="setYear('S84')">Simei</a></li><li><a href="#Somerset (Road)" onclick="setYear('S79')">Somerset (Road)</a></li><li><a href="#Tai Seng" onclick="setYear('S43')">Tai Seng</a></li><li><a href="#Tanjong Katong" onclick="setYear('S78')">Tanjong Katong</a></li><li><a href="#Tanjong Pagar" onclick="setYear('S72')">Tanjong Pagar</a></li><li><a hre ...

# %%
#test call list items into list
stations_list = weather_station[1].find_all('li')
stations_list[-1]
# Out:
# <li><a href="#Yishun" onclick="setYear('S91')">Yishun</a></li>

# %%
#getting station details for downloading
#create soup object with html parser
nea_url = "http://www.weather.gov.sg/climate-historical-daily/"
weather_res = requests.get(nea_url)
weather_soup = BeautifulSoup(weather_res.content, 'html.parser')

#isolate list
weather_station = weather_soup.find_all('ul', {'class': 'dropdown-menu'})

#call list items into list
stations_list = weather_station[1].find_all('li')

#strip and extract station details into dictionary
stations_dict = {}

for i, station in enumerate(stations_list):
    station_name = stations_list[i].text.strip()
    station_id = stations_list[i].find('a')['onclick'].split("'")[1]
    stations_dict[i] = {'name': station_name, 'id': station_id}

# %%
#strip and extract station details into dictionary
stations_dict = {}

for i, station in enumerate(stations_list):
    station_name = stations_list[i].text.strip()
    station_id = stations_list[i].find('a')['onclick'].split("'")[1]
    stations_dict[i] = {'name': station_name, 'id': station_id}

# %% [markdown]
# The above code allows us to match the station name to the station ID. Now, we will download all the CSVs for the different stations, years and months.

# %%
base_url = "http://www.weather.gov.sg/files/dailydata/DAILYDATA_{}_{:04d}{:02d}.csv"
output_directory = "../data/weather_data"

if not os.path.exists(output_directory):
    os.makedirs(output_directory)

csv_files = []  # List to store file paths
master_dfs = []  # List to store individual DataFrames

for n, station in stations_dict.items():
   for year in range(2000, 2024):
        for month in range(1, 13):
            url = base_url.format(station['id'], year, month)
            response = requests.get(url)
       
            if response.status_code == 200:
                file_name = f"DAILYDATA_{station['id']}_{year}{month:02d}.csv"
                csv_files.append(file_name)
           
                # Detect encoding
                encoding = chardet.detect(response.content)['encoding']
           
                # Read content as DataFrame
                month_df = pd.read_csv(BytesIO(response.content), encoding=encoding)
                master_dfs.append(month_df)
                print(f"Downloaded and appended: {station['name']}({station['id']})_{year}-{month:02d}")
            else:
                print(f"Failed to download: {station['name']}({station['id']})_{year}-{month:02d}")
    #optionl cooldown timer per paper to lower hashrate and prevent kick out.
#            cooldown_time = random.uniform(0.1, 2.5)
#            time.sleep(cooldown_time)
                
# Concatenate all individual DataFrames into a single master DataFrame
master_df = pd.concat(master_dfs, ignore_index=True)

# Save the concatenated DataFrame to the master CSV file
master_csv_path = "../data/weather_data/master_weather_data.csv"
master_df.to_csv(master_csv_path, index=False)

print("Master CSV file saved.")
# Out:
# Failed to download: Admiralty(S104)_2000-01
# Failed to download: Admiralty(S104)_2000-02
# Failed to download: Admiralty(S104)_2000-03
# Failed to download: Admiralty(S104)_2000-04
# Failed to download: Admiralty(S104)_2000-05
# Failed to download: Admiralty(S104)_2000-06
# Failed to download: Admiralty(S104)_2000-07
# Failed to download: Admiralty(S104)_2000-08
# Failed to download: Admiralty(S104)_2000-09
# Failed to download: Admiralty(S104)_2000-10
# Failed to download: Admiralty(S104)_2000-11
# Failed to download: Admiralty(S104)_2000-12
# Failed to download: Admiralty(S104)_2001-01
# Failed to download: Admiralty(S104)_2001-02
# Failed to download: Admiralty(S104)_2001-03
# Failed to download: Admiralty(S104)_2001-04
# Failed to download: Admiralty(S104)_2001-05
# Failed to download: Admiralty(S104)_2001-06
# Failed to download: Admiralty(S104)_2001-07
# Failed to download: Admiralty(S104)_2001-08
# Failed to download: Admiralty(S104)_2001-09
# Failed to download: Admiralty(S104)_2001-10
# Failed to download: Admiralty(S104)_2001-11
# Failed to download: Admiralty(S104)_2001-12
# Failed to download: Admiralty(S104)_2002-01
# Failed to download: Admiralty(S104)_2002-02
# Failed to download: Admiralty(S104)_2002-03
# Failed to download: Admiralty(S104)_2002-04
# Failed to download: Admiralty(S104)_2002-05
# Failed to download: Admiralty(S104)_2002-06
# Failed to download: Admiralty(S104)_2002-07
# Failed to download: Admiralty(S104)_2002-08
# Failed to download: Admiralty(S104)_2002-09
# Failed to download: Admiralty(S104)_2002-10
# Failed to download: Admiralty(S104)_2002-11
# Downloaded and appended: Admiralty West(S105)_2011-08
# Downloaded and appended: Admiralty West(S105)_2011-09
# Downloaded and appended: Admiralty West(S105)_2011-10
# Downloaded and appended: Admiralty West(S105)_2011-11
# Downloaded and appended: Admiralty West(S105)_2011-12
# Downloaded and appended: Admiralty West(S105)_2012-01
# Downloaded and appended: Admiralty West(S105)_2012-02
# Downloaded and appended: Admiralty West(S105)_2012-03
# Downloaded and appended: Admiralty West(S105)_2012-04
# Downloaded and appended: Admiralty West(S105)_2012-05
# Downloaded and appended: Admiralty West(S105)_2012-06
# Downloaded and appended: Admiralty West(S105)_2012-07
# Downloaded and appended: Admiralty West(S105)_2012-08
# Downloaded and appended: Admiralty West(S105)_2012-09
# Downloaded and appended: Admiralty West(S105)_2012-10
# Downloaded and appended: Admiralty West(S105)_2012-11
# Downloaded and appended: Admiralty West(S105)_2012-12
# Downloaded and appended: Admiralty West(S105)_2013-01
# Downloaded and appended: Admiralty West(S105)_2013-02
# Downloaded and appended: Admiralty West(S105)_2013-03
# Downloaded and appended: Admiralty West(S105)_2013-04
# Downloaded and appended: Admiralty West(S105)_2013-05
# Downloaded and appended: Admiralty West(S105)_2013-06
# Downloaded and appended: Admiralty West(S105)_2013-07
# Downloaded and appended: Admiralty West(S105)_2013-08
# Downloaded and appended: Admiralty West(S105)_2013-09
# Downloaded and appended: Admiralty West(S105)_2013-10
# Downloaded and appended: Admiralty West(S105)_2013-11
# Downloaded and appended: Admiralty West(S105)_2013-12
# Downloaded and appended: Admiralty West(S105)_2014-01
# Downloaded and appended: Admiralty West(S105)_2014-02
# Downloaded and appended: Admiralty West(S105)_2014-03
# Downloaded and appended: Admiralty West(S105)_2014-04
# Downloaded and appended: Admiralty West(S105)_2014-05
# Downloaded and appended: Admiralty West(S105)_2014-06
# Downloaded and appended: Admiralty West(S105)_2014-07
# Downloaded and appended: Admiralty West(S105)_2014-08
# Downloaded and appended: Admiralty West(S105)_2014-09
# Downloaded and appended: Admiralty West(S105)_2014-10
# Downloaded and appended: Admiralty West(S105)_2014-11
# Downloaded and appended: Admiralty West(S105)_2014-12
# Downloaded and appended: Admiralty West(S105)_2015-01
# Downloaded and appended: Admiralty West(S105)_2015-02
# Downloaded and appended: Admiralty West(S105)_2015-03
# Downloaded and appended: Admiralty West(S105)_2015-04
# Downloaded and appended: Admiralty West(S105)_2015-05
# Downloaded and appended: Admiralty West(S105)_2015-06
# Downloaded and appended: Admiralty West(S105)_2015-07
# Downloaded and appended: Admiralty West(S105)_2015-08
# Downloaded and appended: Admiralty West(S105)_2015-09
# Downloaded and appended: Admiralty West(S105)_2015-10
# Downloaded and appended: Admiralty West(S105)_2015-11
# Downloaded and appended: Admiralty West(S105)_2015-12
# Downloaded and appended: Admiralty West(S105)_2016-01
# Downloaded and appended: Admiralty West(S105)_2016-02
# Downloaded and appended: Admiralty West(S105)_2016-03
# Downloaded and appended: Admiralty West(S105)_2016-04
# Downloaded and appended: Admiralty West(S105)_2016-05
# Downloaded and appended: Admiralty West(S105)_2016-06
# Downloaded and appended: Admiralty West(S105)_2016-07
# Failed to download: Ang Mo Kio(S109)_2008-04
# Failed to download: Ang Mo Kio(S109)_2008-05
# Failed to download: Ang Mo Kio(S109)_2008-06
# Failed to download: Ang Mo Kio(S109)_2008-07
# Failed to download: Ang Mo Kio(S109)_2008-08
# Failed to download: Ang Mo Kio(S109)_2008-09
# Failed to download: Ang Mo Kio(S109)_2008-10
# Failed to download: Ang Mo Kio(S109)_2008-11
# Failed to download: Ang Mo Kio(S109)_2008-12
# Failed to download: Ang Mo Kio(S109)_2009-01
# Failed to download: Ang Mo Kio(S109)_2009-02
# Failed to download: Ang Mo Kio(S109)_2009-03
# Failed to download: Ang Mo Kio(S109)_2009-04
# Failed to download: Ang Mo Kio(S109)_2009-05
# Failed to download: Ang Mo Kio(S109)_2009-06
# Failed to download: Ang Mo Kio(S109)_2009-07
# Failed to download: Ang Mo Kio(S109)_2009-08
# Downloaded and appended: Ang Mo Kio(S109)_2009-09
# Downloaded and appended: Ang Mo Kio(S109)_2009-10
# Downloaded and appended: Ang Mo Kio(S109)_2009-11
# Downloaded and appended: Ang Mo Kio(S109)_2009-12
# Downloaded and appended: Ang Mo Kio(S109)_2010-01
# Downloaded and appended: Ang Mo Kio(S109)_2010-02
# Downloaded and appended: Ang Mo Kio(S109)_2010-03
# Downloaded and appended: Ang Mo Kio(S109)_2010-04
# Downloaded and appended: Ang Mo Kio(S109)_2010-05
# Downloaded and appended: Ang Mo Kio(S109)_2010-06
# Downloaded and appended: Ang Mo Kio(S109)_2010-07
# Downloaded and appended: Ang Mo Kio(S109)_2010-08
# Downloaded and appended: Ang Mo Kio(S109)_2010-09
# Downloaded and appended: Ang Mo Kio(S109)_2010-10
# Downloaded and appended: Ang Mo Kio(S109)_2010-11
# Downloaded and appended: Ang Mo Kio(S109)_2010-12
# Downloaded and appended: Ang Mo Kio(S109)_2011-01
# Downloaded and appended: Ang Mo Kio(S109)_2011-02
# Downloaded and appended: Ang Mo Kio(S109)_2011-03
# Downloaded and appended: Ang Mo Kio(S109)_2011-04
# Downloaded and appended: Ang Mo Kio(S109)_2011-05
# Downloaded and appended: Ang Mo Kio(S109)_2011-06
# Downloaded and appended: Ang Mo Kio(S109)_2011-07
# Downloaded and appended: Ang Mo Kio(S109)_2011-08
# Downloaded and appended: Ang Mo Kio(S109)_2011-09
# Downloaded and appended: Ang Mo Kio(S109)_2011-10
# Downloaded and appended: Ang Mo Kio(S109)_2011-11
# Downloaded and appended: Ang Mo Kio(S109)_2011-12
# Downloaded and appended: Ang Mo Kio(S109)_2012-01
# Downloaded and appended: Ang Mo Kio(S109)_2012-02
# Downloaded and appended: Ang Mo Kio(S109)_2012-03
# Downloaded and appended: Ang Mo Kio(S109)_2012-04
# Downloaded and appended: Ang Mo Kio(S109)_2012-05
# Downloaded and appended: Ang Mo Kio(S109)_2012-06
# Downloaded and appended: Ang Mo Kio(S109)_2012-07
# Downloaded and appended: Ang Mo Kio(S109)_2012-08
# Downloaded and appended: Ang Mo Kio(S109)_2012-09
# Downloaded and appended: Ang Mo Kio(S109)_2012-10
# Downloaded and appended: Ang Mo Kio(S109)_2012-11
# Downloaded and appended: Ang Mo Kio(S109)_2012-12
# Downloaded and appended: Ang Mo Kio(S109)_2013-01
# Downloaded and appended: Ang Mo Kio(S109)_2013-02
# Downloaded and appended: Ang Mo Kio(S109)_2013-03
# Downloaded and appended: Ang Mo Kio(S109)_2013-04
# Downloaded and appended: Ang Mo Kio(S109)_2013-05
# Downloaded and appended: Ang Mo Kio(S109)_2013-06
# Downloaded and appended: Ang Mo Kio(S109)_2013-07
# Downloaded and appended: Ang Mo Kio(S109)_2013-08
# Downloaded and appended: Ang Mo Kio(S109)_2013-09
# Downloaded and appended: Ang Mo Kio(S109)_2013-10
# Downloaded and appended: Ang Mo Kio(S109)_2013-11
# Downloaded and appended: Ang Mo Kio(S109)_2013-12
# Downloaded and appended: Ang Mo Kio(S109)_2014-01
# Downloaded and appended: Ang Mo Kio(S109)_2014-02
# Downloaded and appended: Ang Mo Kio(S109)_2014-03
# Downloaded and appended: Ang Mo Kio(S109)_2014-04
# Downloaded and appended: Ang Mo Kio(S109)_2014-05
# Downloaded and appended: Ang Mo Kio(S109)_2014-06
# Downloaded and appended: Ang Mo Kio(S109)_2014-07
# Downloaded and appended: Ang Mo Kio(S109)_2014-08
# Downloaded and appended: Ang Mo Kio(S109)_2014-09
# Downloaded and appended: Ang Mo Kio(S109)_2014-10
# Downloaded and appended: Ang Mo Kio(S109)_2014-11
# Downloaded and appended: Ang Mo Kio(S109)_2014-12
# Downloaded and appended: Ang Mo Kio(S109)_2015-01
# Downloaded and appended: Ang Mo Kio(S109)_2015-02
# Downloaded and appended: Ang Mo Kio(S109)_2015-03
# Downloaded and appended: Ang Mo Kio(S109)_2015-04
# Downloaded and appended: Ang Mo Kio(S109)_2015-05
# Downloaded and appended: Ang Mo Kio(S109)_2015-06
# Downloaded and appended: Ang Mo Kio(S109)_2015-07
# Downloaded and appended: Ang Mo Kio(S109)_2015-08
# Downloaded and appended: Ang Mo Kio(S109)_2015-09
# Downloaded and appended: Ang Mo Kio(S109)_2015-10
# Downloaded and appended: Ang Mo Kio(S109)_2015-11
# Downloaded and appended: Ang Mo Kio(S109)_2015-12
# Downloaded and appended: Ang Mo Kio(S109)_2016-01
# Downloaded and appended: Ang Mo Kio(S109)_2016-02
# Downloaded and appended: Ang Mo Kio(S109)_2016-03
# Downloaded and appended: Ang Mo Kio(S109)_2016-04
# Downloaded and appended: Ang Mo Kio(S109)_2016-05
# Downloaded and appended: Ang Mo Kio(S109)_2016-06
# Downloaded and appended: Ang Mo Kio(S109)_2016-07
# Downloaded and appended: Ang Mo Kio(S109)_2016-08
# Downloaded and appended: Ang Mo Kio(S109)_2016-09
# Downloaded and appended: Ang Mo Kio(S109)_2016-10
# Downloaded and appended: Ang Mo Kio(S109)_2016-11
# Downloaded and appended: Ang Mo Kio(S109)_2016-12
# Downloaded and appended: Ang Mo Kio(S109)_2017-01
# Downloaded and appended: Ang Mo Kio(S109)_2017-02
# Downloaded and appended: Ang Mo Kio(S109)_2017-03
# Downloaded and appended: Ang Mo Kio(S109)_2017-04
# Downloaded and appended: Ang Mo Kio(S109)_2017-05
# Downloaded and appended: Ang Mo Kio(S109)_2017-06
# Downloaded and appended: Ang Mo Kio(S109)_2017-07
# Downloaded and appended: Ang Mo Kio(S109)_2017-08
# Downloaded and appended: Ang Mo Kio(S109)_2017-09
# Downloaded and appended: Ang Mo Kio(S109)_2017-10
# Downloaded and appended: Ang Mo Kio(S109)_2017-11
# Downloaded and appended: Ang Mo Kio(S109)_2017-12
# Downloaded and appended: Ang Mo Kio(S109)_2018-01
# Downloaded and appended: Ang Mo Kio(S109)_2018-02
# Downloaded and appended: Ang Mo Kio(S109)_2018-03
# Downloaded and appended: Ang Mo Kio(S109)_2018-04
# Downloaded and appended: Ang Mo Kio(S109)_2018-05
# Downloaded and appended: Ang Mo Kio(S109)_2018-06
# Downloaded and appended: Ang Mo Kio(S109)_2018-07
# Downloaded and appended: Ang Mo Kio(S109)_2018-08
# Downloaded and appended: Ang Mo Kio(S109)_2018-09
# Downloaded and appended: Ang Mo Kio(S109)_2018-10
# Downloaded and appended: Ang Mo Kio(S109)_2018-11
# Downloaded and appended: Ang Mo Kio(S109)_2018-12
# Downloaded and appended: Ang Mo Kio(S109)_2019-01
# Downloaded and appended: Ang Mo Kio(S109)_2019-02
# Downloaded and appended: Ang Mo Kio(S109)_2019-03
# Downloaded and appended: Ang Mo Kio(S109)_2019-04
# Downloaded and appended: Ang Mo Kio(S109)_2019-05
# Downloaded and appended: Ang Mo Kio(S109)_2019-06
# Downloaded and appended: Ang Mo Kio(S109)_2019-07
# Downloaded and appended: Ang Mo Kio(S109)_2019-08
# Downloaded and appended: Ang Mo Kio(S109)_2019-09
# Downloaded and appended: Ang Mo Kio(S109)_2019-10
# Downloaded and appended: Ang Mo Kio(S109)_2019-11
# Downloaded and appended: Ang Mo Kio(S109)_2019-12
# Downloaded and appended: Ang Mo Kio(S109)_2020-01
# Downloaded and appended: Ang Mo Kio(S109)_2020-02
# Downloaded and appended: Ang Mo Kio(S109)_2020-03
# Downloaded and appended: Ang Mo Kio(S109)_2020-04
# Downloaded and appended: Ang Mo Kio(S109)_2020-05
# Downloaded and appended: Ang Mo Kio(S109)_2020-06
# Downloaded and appended: Ang Mo Kio(S109)_2020-07
# Downloaded and appended: Ang Mo Kio(S109)_2020-08
# Downloaded and appended: Ang Mo Kio(S109)_2020-09
# Downloaded and appended: Ang Mo Kio(S109)_2020-10
# Downloaded and appended: Ang Mo Kio(S109)_2020-11
# Downloaded and appended: Ang Mo Kio(S109)_2020-12
# Downloaded and appended: Ang Mo Kio(S109)_2021-01
# Downloaded and appended: Ang Mo Kio(S109)_2021-02
# Downloaded and appended: Ang Mo Kio(S109)_2021-03
# Downloaded and appended: Ang Mo Kio(S109)_2021-04
# Downloaded and appended: Ang Mo Kio(S109)_2021-05
# Downloaded and appended: Ang Mo Kio(S109)_2021-06
# Downloaded and appended: Ang Mo Kio(S109)_2021-07
# Downloaded and appended: Ang Mo Kio(S109)_2021-08
# Downloaded and appended: Ang Mo Kio(S109)_2021-09
# Downloaded and appended: Ang Mo Kio(S109)_2021-10
# Downloaded and appended: Ang Mo Kio(S109)_2021-11
# Downloaded and appended: Ang Mo Kio(S109)_2021-12
# Downloaded and appended: Ang Mo Kio(S109)_2022-01
# Downloaded and appended: Ang Mo Kio(S109)_2022-02
# Downloaded and appended: Ang Mo Kio(S109)_2022-03
# Downloaded and appended: Ang Mo Kio(S109)_2022-04
# Downloaded and appended: Ang Mo Kio(S109)_2022-05
# Downloaded and appended: Ang Mo Kio(S109)_2022-06
# Downloaded and appended: Ang Mo Kio(S109)_2022-07
# Downloaded and appended: Ang Mo Kio(S109)_2022-08
# Downloaded and appended: Ang Mo Kio(S109)_2022-09
# Downloaded and appended: Ang Mo Kio(S109)_2022-10
# Downloaded and appended: Ang Mo Kio(S109)_2022-11
# Downloaded and appended: Ang Mo Kio(S109)_2022-12
# Downloaded and appended: Ang Mo Kio(S109)_2023-01
# Downloaded and appended: Ang Mo Kio(S109)_2023-02
# Downloaded and appended: Ang Mo Kio(S109)_2023-03
# Downloaded and appended: Ang Mo Kio(S109)_2023-04
# Downloaded and appended: Ang Mo Kio(S109)_2023-05
# Downloaded and appended: Ang Mo Kio(S109)_2023-06
# Downloaded and appended: Ang Mo Kio(S109)_2023-07
# Failed to download: Ang Mo Kio(S109)_2023-08
# Failed to download: Ang Mo Kio(S109)_2023-09
# Failed to download: Ang Mo Kio(S109)_2023-10
# Failed to download: Ang Mo Kio(S109)_2023-11
# Failed to download: Ang Mo Kio(S109)_2023-12
# Failed to download: Boon Lay (East)(S86)_2000-01
# Failed to download: Boon Lay (East)(S86)_2000-02
# Failed to download: Boon Lay (East)(S86)_2000-03
# Failed to download: Boon Lay (East)(S86)_2000-04
# Failed to download: Boon Lay (East)(S86)_2000-05
# Failed to download: Boon Lay (East)(S86)_2000-06
# Failed to download: Boon Lay (East)(S86)_2000-07
# Failed to download: Boon Lay (East)(S86)_2000-08
# Failed to download: Boon Lay (East)(S86)_2000-09
# Failed to download: Boon Lay (East)(S86)_2000-10
# Failed to download: Boon Lay (East)(S86)_2000-11
# Failed to download: Boon Lay (East)(S86)_2000-12
# Failed to download: Boon Lay (East)(S86)_2001-01
# Failed to download: Boon Lay (East)(S86)_2001-02
# Failed to download: Boon Lay (East)(S86)_2001-03
# Failed to download: Boon Lay (East)(S86)_2001-04
# Failed to download: Boon Lay (East)(S86)_2001-05
# Failed to download: Boon Lay (East)(S86)_2001-06
# Failed to download: Boon Lay (East)(S86)_2001-07
# Failed to download: Boon Lay (East)(S86)_2001-08
# Failed to download: Boon Lay (East)(S86)_2001-09
# Failed to download: Boon Lay (East)(S86)_2001-10
# Failed to download: Boon Lay (East)(S86)_2001-11
# Failed to download: Boon Lay (East)(S86)_2001-12
# Failed to download: Boon Lay (East)(S86)_2002-01
# Failed to download: Boon Lay (East)(S86)_2002-02
# Failed to download: Boon Lay (East)(S86)_2002-03
# Failed to download: Boon Lay (East)(S86)_2002-04
# Failed to download: Boon Lay (East)(S86)_2002-05
# Failed to download: Boon Lay (East)(S86)_2002-06
# Failed to download: Boon Lay (East)(S86)_2002-07
# Failed to download: Boon Lay (East)(S86)_2002-08
# Failed to download: Boon Lay (East)(S86)_2007-09
# Failed to download: Boon Lay (East)(S86)_2007-10
# Failed to download: Boon Lay (East)(S86)_2007-11
# Failed to download: Boon Lay (East)(S86)_2007-12
# Failed to download: Boon Lay (East)(S86)_2008-01
# Failed to download: Boon Lay (East)(S86)_2008-02
# Failed to download: Boon Lay (East)(S86)_2008-03
# Failed to download: Boon Lay (East)(S86)_2008-04
# Failed to download: Boon Lay (East)(S86)_2008-05
# Failed to download: Boon Lay (East)(S86)_2008-06
# Failed to download: Boon Lay (East)(S86)_2008-07
# Failed to download: Boon Lay (East)(S86)_2008-08
# Failed to download: Boon Lay (East)(S86)_2008-09
# Failed to download: Boon Lay (East)(S86)_2008-10
# Failed to download: Boon Lay (East)(S86)_2008-11
# Failed to download: Boon Lay (East)(S86)_2008-12
# Failed to download: Boon Lay (East)(S86)_2009-01
# Failed to download: Boon Lay (East)(S86)_2009-02
# Failed to download: Boon Lay (East)(S86)_2009-03
# Failed to download: Boon Lay (East)(S86)_2009-04
# Failed to download: Boon Lay (East)(S86)_2009-05
# Failed to download: Boon Lay (East)(S86)_2009-06
# Failed to download: Boon Lay (East)(S86)_2009-07
# Failed to download: Boon Lay (East)(S86)_2009-08
# Failed to download: Boon Lay (East)(S86)_2009-09
# Failed to download: Boon Lay (East)(S86)_2009-10
# Downloaded and appended: Boon Lay (East)(S86)_2009-11
# Downloaded and appended: Boon Lay (East)(S86)_2009-12
# Downloaded and appended: Boon Lay (East)(S86)_2010-01
# ...
# Downloaded and appended: Whampoa(S123)_2017-05
# Downloaded and appended: Whampoa(S123)_2017-06
# Downloaded and appended: Whampoa(S123)_2017-07
# Downloaded and appended: Whampoa(S123)_2017-08
# Downloaded and appended: Whampoa(S123)_2017-09
# Downloaded and appended: Whampoa(S123)_2017-10
# Downloaded and appended: Whampoa(S123)_2017-11
# Downloaded and appended: Whampoa(S123)_2017-12
# Downloaded and appended: Whampoa(S123)_2018-01
# Downloaded and appended: Whampoa(S123)_2018-02
# Downloaded and appended: Whampoa(S123)_2018-03
# Downloaded and appended: Whampoa(S123)_2018-04
# Downloaded and appended: Whampoa(S123)_2018-05
# Downloaded and appended: Whampoa(S123)_2018-06
# Downloaded and appended: Whampoa(S123)_2018-07
# Downloaded and appended: Whampoa(S123)_2018-08
# Downloaded and appended: Whampoa(S123)_2018-09
# Downloaded and appended: Whampoa(S123)_2018-10
# Downloaded and appended: Whampoa(S123)_2018-11
# Downloaded and appended: Whampoa(S123)_2018-12
# Downloaded and appended: Whampoa(S123)_2019-01
# Downloaded and appended: Whampoa(S123)_2019-02
# Downloaded and appended: Whampoa(S123)_2019-03
# Downloaded and appended: Whampoa(S123)_2019-04
# Downloaded and appended: Whampoa(S123)_2019-05
# Downloaded and appended: Whampoa(S123)_2019-06
# Downloaded and appended: Whampoa(S123)_2019-07
# Downloaded and appended: Whampoa(S123)_2019-08
# Downloaded and appended: Whampoa(S123)_2019-09
# Downloaded and appended: Whampoa(S123)_2019-10
# Downloaded and appended: Whampoa(S123)_2019-11
# Downloaded and appended: Whampoa(S123)_2019-12
# Downloaded and appended: Whampoa(S123)_2020-01
# Downloaded and appended: Whampoa(S123)_2020-02
# Downloaded and appended: Whampoa(S123)_2020-03
# Downloaded and appended: Whampoa(S123)_2020-04
# Downloaded and appended: Whampoa(S123)_2020-05
# Downloaded and appended: Whampoa(S123)_2020-06
# Downloaded and appended: Whampoa(S123)_2020-07
# Downloaded and appended: Whampoa(S123)_2020-08
# Downloaded and appended: Whampoa(S123)_2020-09
# Downloaded and appended: Whampoa(S123)_2020-10
# Downloaded and appended: Whampoa(S123)_2020-11
# Downloaded and appended: Whampoa(S123)_2020-12
# Downloaded and appended: Whampoa(S123)_2021-01
# Downloaded and appended: Whampoa(S123)_2021-02
# Downloaded and appended: Whampoa(S123)_2021-03
# Downloaded and appended: Whampoa(S123)_2021-04
# Downloaded and appended: Whampoa(S123)_2021-05
# Downloaded and appended: Whampoa(S123)_2021-06
# Downloaded and appended: Whampoa(S123)_2021-07
# Downloaded and appended: Whampoa(S123)_2021-08
# Downloaded and appended: Whampoa(S123)_2021-09
# Downloaded and appended: Whampoa(S123)_2021-10
# Downloaded and appended: Whampoa(S123)_2021-11
# Downloaded and appended: Whampoa(S123)_2021-12
# Downloaded and appended: Whampoa(S123)_2022-01
# Downloaded and appended: Whampoa(S123)_2022-02
# Downloaded and appended: Whampoa(S123)_2022-03
# Downloaded and appended: Whampoa(S123)_2022-04
# Downloaded and appended: Whampoa(S123)_2022-05
# Downloaded and appended: Whampoa(S123)_2022-06
# Downloaded and appended: Whampoa(S123)_2022-07
# Downloaded and appended: Whampoa(S123)_2022-08
# Downloaded and appended: Whampoa(S123)_2022-09
# Downloaded and appended: Whampoa(S123)_2022-10
# Downloaded and appended: Whampoa(S123)_2022-11
# Downloaded and appended: Whampoa(S123)_2022-12
# Downloaded and appended: Whampoa(S123)_2023-01
# Downloaded and appended: Whampoa(S123)_2023-02
# Downloaded and appended: Whampoa(S123)_2023-03
# Downloaded and appended: Whampoa(S123)_2023-04
# Downloaded and appended: Whampoa(S123)_2023-05
# Downloaded and appended: Whampoa(S123)_2023-06
# Downloaded and appended: Whampoa(S123)_2023-07
# Failed to download: Whampoa(S123)_2023-08
# Failed to download: Whampoa(S123)_2023-09
# Failed to download: Whampoa(S123)_2023-10
# Failed to download: Whampoa(S123)_2023-11
# Failed to download: Whampoa(S123)_2023-12
# Failed to download: Yishun(S91)_2000-01
# Failed to download: Yishun(S91)_2000-02
# Failed to download: Yishun(S91)_2000-03
# Failed to download: Yishun(S91)_2000-04
# Failed to download: Yishun(S91)_2000-05
# Failed to download: Yishun(S91)_2000-06
# Failed to download: Yishun(S91)_2000-07
# Failed to download: Yishun(S91)_2000-08
# Failed to download: Yishun(S91)_2000-09
# Failed to download: Yishun(S91)_2000-10
# Failed to download: Yishun(S91)_2000-11
# Failed to download: Yishun(S91)_2000-12
# Failed to download: Yishun(S91)_2001-01
# Failed to download: Yishun(S91)_2001-02
# Failed to download: Yishun(S91)_2001-03
# Failed to download: Yishun(S91)_2001-04
# Failed to download: Yishun(S91)_2001-05
# Failed to download: Yishun(S91)_2001-06
# One issue is that if we pull data for 5 years and above, it will give us monthly search trends, as opposed to weekly search trends if we pull data for less than 5 years. Thus, we will do 3 pulls that are less than 5 years so that we can get weekly data. We will also have an overlap of one year between each pull so that we can scale the overlapping data. This allows us to get weekly data over the course of 12 years.

# %% [markdown]
# ### 2.1 'dengue' Search

# %%
# Set up the pytrends object
pytrends = TrendReq(hl='en-US', tz=360, backoff_factor=0.1)

# Define search term and geographical location
search_term = 'dengue'
geo_location = 'SG'
period1 = '2012-01-01 2015-12-31'
period2 = '2015-01-01 2019-12-31'
period3 = '2019-01-01 2023-08-06'
periods = [period1, period2, period3]

for i, period in enumerate(periods):
    # Build the payload
    pytrends.build_payload([search_term], cat=0, timeframe = period, geo = geo_location, gprop='')

    # Get the weekly search interest data
    interest_data = pytrends.interest_over_time()

    # Save the data to a CSV file
    file_path = f"../data/google_data/{search_term}_search_interest{i+1}.csv"
    interest_data.to_csv(file_path, index=True)

# %% [markdown]
# ### 2.2 'dengue symptoms' Search

# %%
# Set up the pytrends object
pytrends = TrendReq(hl='en-US', tz=360, backoff_factor=0.1)

# Define search term and geographical location
search_term = 'dengue symptoms'
geo_location = 'SG'
period1 = '2012-01-01 2015-12-31'
period2 = '2015-01-01 2019-12-31'
period3 = '2019-01-01 2023-08-06'
periods = [period1, period2, period3]

for i, period in enumerate(periods):
    # Build the payload
    pytrends.build_payload([search_term], cat=0, timeframe = period, geo = geo_location, gprop='')

    # Get the weekly search interest data
    interest_data = pytrends.interest_over_time()

    # Save the data to a CSV file
    file_path = f"../data/google_data/{search_term}_search_interest{i+1}.csv"
    interest_data.to_csv(file_path, index=True)

# %% [markdown]
# ### 2.3 Combining Multiple Calls (.csv) files
# - Google limitation for datasets more than 5 years are converted to monthly data points.
# - Since each dataset is scaled as percentage, with the peak labelled 100%, combining requires a factor to link each dataset.

# %%
def factorizer(df1, df2, search_term):
    #fix datetime format and set index
    #check df1
    if isinstance(df1.index, pd.DatetimeIndex) == True:
        pass
    else:
        df1.set_index('date', inplace=True)
        df1.index = pd.to_datetime(df1.index, format='%Y-%m-%d')
    #check df2
    if isinstance(df2.index, pd.DatetimeIndex) == True:
        pass
    else:
        df2.set_index('date', inplace=True)
        df2.index = pd.to_datetime(df2.index, format='%Y-%m-%d')

    #slice up df by year and merge
    df_match_year = df1.merge(df2, how = 'inner', left_index = True, right_index = True, suffixes = ('_1', '_2'))

    #calculate adjustment factor (k), averaged over a year.
    df_match_year['difference'] = df_match_year[f'{search_term}_2']/df_match_year[f'{search_term}_1']
    factor = df_match_year['difference'].mean()
    print(f"Factor (k) for adjusting scale of data in first df to second df is {factor:.4f}.")

    #apply k factor, drop rows of common year, concat datafram vertically (axis =0)
    df1[f'{search_term}'] *= factor
    df1.drop(index = df_match_year.index, inplace = True)
    df1 = pd.concat([df1, df2], axis = 0)
    
    return df1

# %% [markdown]
# #### 2.3.1 Combining 'dengue' Searches

# %%
#import 
dengue_search_interest1 = pd.read_csv('../data/google_data/dengue_search_interest1.csv')
dengue_search_interest2 = pd.read_csv('../data/google_data/dengue_search_interest2.csv')
dengue_search_interest3 = pd.read_csv('../data/google_data/dengue_search_interest3.csv')

# %%
#apply factorizer
dengue_search_partial = factorizer(dengue_search_interest1, dengue_search_interest2, 'dengue')
dengue_search_combined = factorizer(dengue_search_partial, dengue_search_interest3, 'dengue')
dengue_search_combined
# Out:
# Factor (k) for adjusting scale of data in first df to second df is 2.7819.
# Factor (k) for adjusting scale of data in first df to second df is 0.5714.
#                dengue  isPartial
# date
# 2012-01-01  11.127111      False
# 2012-01-08   6.358349      False
# 2012-01-15   6.358349      False
# 2012-01-22  11.127111      False
# 2012-01-29   7.947936      False
# ...               ...        ...
# 2023-07-09  19.000000      False
# 2023-07-16  19.000000      False
# 2023-07-23  21.000000      False
# 2023-07-30  17.000000      False
# 2023-08-06  16.000000      False
#
# [606 rows x 2 columns]

# %%
#export csv
dengue_search_combined.to_csv('../data/google_data/master_dengue_search_data.csv', index=True)

# %% [markdown]
# #### 2.3.2 Combining 'dengue symptoms' Searches

# %%
#import 
dengue_symptoms_search_interest1 = pd.read_csv('../data/google_data/dengue symptoms_search_interest1.csv')
dengue_symptoms_search_interest2 = pd.read_csv('../data/google_data/dengue symptoms_search_interest2.csv')
dengue_symptoms_search_interest3 = pd.read_csv('../data/google_data/dengue symptoms_search_interest3.csv')

# %%
#apply factorizer
dengue_symptoms_search_partial = factorizer(dengue_symptoms_search_interest1, 
                                            dengue_symptoms_search_interest2, 
                                            'dengue symptoms')
dengue_symptoms_search_combined = factorizer(dengue_symptoms_search_partial, 
                                             dengue_symptoms_search_interest3,
                                            'dengue symptoms')
dengue_symptoms_search_combined
# Out:
# Factor (k) for adjusting scale of data in first df to second df is 3.5201.
# Factor (k) for adjusting scale of data in first df to second df is 0.6476.
#             dengue symptoms  isPartial
# date
# 2012-01-01         6.838475      False
# 2012-01-08         0.000000      False
# 2012-01-15        18.235933      False
# 2012-01-22        18.235933      False
# 2012-01-29         9.117967      False
# ...                     ...        ...
# 2023-07-09        20.000000      False
# 2023-07-16        21.000000      False
# 2023-07-23        28.000000      False
# 2023-07-30        23.000000      False
# 2023-08-06        23.000000      False
#
# [606 rows x 2 columns]

# %%
#export csv
dengue_symptoms_search_combined.to_csv('../data/google_data/master_dengue_symptoms_search_data.csv', index=True)

# %% [markdown]
# ## 3. Dengue Data

# %% [markdown]
# For dengue data, we will use the data from data.gov.sg.

# %%
dengue = pd.read_csv('../data/dengue_data/WeeklyInfectiousDiseaseBulletinCases.csv')

# %%
dengue
# Out:
#        epi_week                  disease  no._of_cases
# 0      2012-W01  Acute Viral hepatitis B             0
# 1      2012-W01  Acute Viral hepatitis C             0
# 2      2012-W01          Avian Influenza             0
# 3      2012-W01   Campylobacterenterosis             6
# 4      2012-W01        Chikungunya Fever             0
# ...         ...                      ...           ...
# 20065  2022-W52    Japanese Encephalitis             0
# 20066  2022-W52                  Tetanus             0
# 20067  2022-W52                 Botulism             0
# 20068  2022-W52            Murine Typhus             0
# 20069  2022-W52                Monkeypox             0
#
# [20070 rows x 3 columns]

# %%
#export csv
dengue.to_csv('../data/dengue_data/WeeklyInfectiousDiseaseBulletinCases.csv', index=False)
